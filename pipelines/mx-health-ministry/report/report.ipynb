# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# %%
plt.rcParams["figure.figsize"] = (8,8)

# %%
confirmed = pd.read_csv('https://mx-covid-data.s3-us-west-1.amazonaws.com/mx-health-ministry/2020.04.08/confirmed.csv')

# %%
confirmed.head()
# Out:
#    N Caso            Estado       Sexo  Edad Fecha de inicio de síntomas  \
# 0       1        TAMAULIPAS  MASCULINO    22                  04/04/2020
# 1       2  CIUDAD DE MÉXICO  MASCULINO    40                  17/03/2020
# 2       3  CIUDAD DE MÉXICO   FEMENINO    29                  26/03/2020
# 3       4            MÉXICO   FEMENINO    84                  26/03/2020
# 4       5        NUEVO LEÓN  MASCULINO    54                  20/03/2020
#
#   Identificación de COVID-19 por RT-PCR en tiempo real
# 0                                         Confirmado
# 1                                         Confirmado
# 2                                         Confirmado
# 3                                         Confirmado
# 4                                         Confirmado

# %%
sns.distplot(confirmed['Edad'])

# %%
df.groupby('Sexo').size().plot(kind='bar')

# %%
df.groupby('Estado').size().sort_values(ascending=False).plot(kind='bar')
